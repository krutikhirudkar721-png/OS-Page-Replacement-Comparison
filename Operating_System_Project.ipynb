# %% [markdown]
# <a href="https://colab.research.google.com/github/krutikhirudkar721-png/OS-Page-Replacement-Comparison/blob/main/Operating_System_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fifo(reference_string, frames):
    memory = []
    page_faults = 0
    index = 0

    for page in reference_string:
        if page not in memory:
            if len(memory) < frames:
                memory.append(page)
            else:
                memory[index] = page
                index = (index + 1) % frames
            page_faults += 1
        print(f"Page: {page} -> Frames: {memory}")
    return page_faults


def lru(reference_string, frames):
    memory = []
    page_faults = 0

    for i in range(len(reference_string)):
        page = reference_string[i]
        if page not in memory:
            if len(memory) < frames:
                memory.append(page)
            else:
                # Find least recently used page
                lru_page = min(memory, key=lambda x: reference_string[:i][::-1].index(x))
                memory[memory.index(lru_page)] = page
            page_faults += 1
        print(f"Page: {page} -> Frames: {memory}")
    return page_faults


def optimal(reference_string, frames):
    memory = []
    page_faults = 0

    for i in range(len(reference_string)):
        page = reference_string[i]
        if page not in memory:
            if len(memory) < frames:
                memory.append(page)
            else:
                future = reference_string[i + 1:]
                replace_page = None
                farthest = -1

                for mem_page in memory:
                    if mem_page not in future:
                        replace_page = mem_page
                        break
                    else:
                        index = future.index(mem_page)
                        if index > farthest:
                            farthest = index
                            replace_page = mem_page

                memory[memory.index(replace_page)] = page
            page_faults += 1
        print(f"Page: {page} -> Frames: {memory}")
    return page_faults


if __name__ == "__main__":
    reference_string = list(map(int, input("Enter reference string (space-separated): ").split()))
    frames = int(input("Enter number of frames: "))

    print("\n--- FIFO ---")
    fifo_faults = fifo(reference_string, frames)
    print("Total Page Faults (FIFO):", fifo_faults)

    print("\n--- LRU ---")
    lru_faults = lru(reference_string, frames)
    print("Total Page Faults (LRU):", lru_faults)

    print("\n--- Optimal ---")
    optimal_faults = optimal(reference_string, frames)
    print("Total Page Faults (Optimal):", optimal_faults)

    print("\n--- Comparison ---")
    print(f"FIFO: {fifo_faults}")
    print(f"LRU: {lru_faults}")
    print(f"Optimal: {optimal_faults}")
# Out:
# Enter reference string (space-separated): 1 2 3 4 5 6 7 8 9
# Enter number of frames: 3
#
# --- FIFO ---
# Page: 1 -> Frames: [1]
# Page: 2 -> Frames: [1, 2]
# Page: 3 -> Frames: [1, 2, 3]
# Page: 4 -> Frames: [4, 2, 3]
# Page: 5 -> Frames: [4, 5, 3]
# Page: 6 -> Frames: [4, 5, 6]
# Page: 7 -> Frames: [7, 5, 6]
# Page: 8 -> Frames: [7, 8, 6]
# Page: 9 -> Frames: [7, 8, 9]
# Total Page Faults (FIFO): 9
#
# --- LRU ---
# Page: 1 -> Frames: [1]
# Page: 2 -> Frames: [1, 2]
# Page: 3 -> Frames: [1, 2, 3]
# Page: 4 -> Frames: [1, 2, 4]
# Page: 5 -> Frames: [1, 2, 5]
# Page: 6 -> Frames: [1, 2, 6]
# Page: 7 -> Frames: [1, 2, 7]
# Page: 8 -> Frames: [1, 2, 8]
# Page: 9 -> Frames: [1, 2, 9]
# Total Page Faults (LRU): 9
#
# --- Optimal ---
# Page: 1 -> Frames: [1]
# Page: 2 -> Frames: [1, 2]
# Page: 3 -> Frames: [1, 2, 3]
# Page: 4 -> Frames: [4, 2, 3]
# Page: 5 -> Frames: [5, 2, 3]
# Page: 6 -> Frames: [6, 2, 3]
# Page: 7 -> Frames: [7, 2, 3]
# Page: 8 -> Frames: [8, 2, 3]
# Page: 9 -> Frames: [9, 2, 3]
# Total Page Faults (Optimal): 9
#
# --- Comparison ---
# FIFO: 9
# LRU: 9
# Optimal: 9
